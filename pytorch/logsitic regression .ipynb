# %%
import torch 
import torch.nn as nn 
import torchvision 
import torchvision.transforms as transforms

# %%
train , test = 1,1

# %%
# 设置网络的超参数 
input_size = 784
num_classes  = 10 
num_epochs = 5 
batch_size = 100
learning_rate = 0.001

# %%
# 建立网络
model = nn.Linear(input_size , num_classes) #输入形状， 和 层数

# %%
# 设置损失函数为交叉熵
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters() , lr = learning_rate)

# %%
# 迭代训练
for epoch in range(num_epochs):
    for i , (images , labels) in enumerate(train_loader):
        images = images.reshape(-1 , 28*28 )  # -1 代表根据根据列值改变
        
        outputs = model(images)
        loss = criterion(outputs, labels) 
        
        optimal.zero_grad() 
        loss.backword()
        optimizer.step()
        
        if(i+1)%100 == 0 :
            print('Epoch[{}/{}] , Step[{}/{}], Loss : {:.4f}'.format(epoch+1,num_epochs, i+1 , total_step , loss.item()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e6bd8afbfc72> in <module>()
#       1 # 迭代训练
#       2 for epoch in range(num_epochs):
# ----> 3     for i , (images , labels) in enumerate(train_loader):
#       4         images = images.reshape(-1 , 28*28 )  # -1 代表根据根据列值改变
#       5
#
# NameError: name 'train_loader' is not defined

# %%
with
