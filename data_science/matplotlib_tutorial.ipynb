# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

# %matplotlib inline 


x = np.array([1,2,3])
y = np.array([2,4,6] )
plt.plot(x,y)
plt.xlabel('x ')
plt.ylabel('y ')
plt.title('plot')
plt.show()

# %%
s = pd.Series(np.random.rand(10).cumsum(),index=np.arange(0,100,10)) 

plt.plot(s,'r--')


plt.show()

# %%
x = np.array([1,2,3])
y = np.array([2,4,6] )
y2 = np.array([3,6,9])

plt.plot(x,y,color = 'g' , linestyle = '-' ) # 绿色 ， 虚线
plt.plot(x,y2,color = 'r', linestyle = '--') # 红色，虚线
plt.title('different color')

plt.show()

# %% [markdown]
# ### scatter 散点图

# %%
x = np.array([1,2,3])
y = np.array([2,4,6] )
plt.scatter(x,y) #散点图
plt.show()

# %%
x = np.random.rand(10)
y = np.random.rand(10)
plt.scatter(x,y,color='green')
plt.show()

# %%
x ,y = np.random.rand(100), np.random.rand(100)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### 柱状图

# %%
labels = ['Tom', 'Dick', 'Harry', 'Slim', 'Jim']
data = [5, 20, 15, 25, 10]
plt.bar(range(len(data)), data, color ='grby' , tick_label = labels)   # 

plt.show()

# %% [markdown]
# ```python
# bar(left, height, width=0.8, bottom=None, **kwargs)
# ```
# 这四个参数确定了柱体的位置和大小。默认情况下，left为柱体的居中位置
# - (left - width / 2, bottom)为左下角位置
# - (left + width / 2, bottom + height)为右上角位置

# %% [markdown]
# ### 条形图

# %%
data = [5, 20, 15, 25, 10]

plt.barh(range(len(data)), data)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([5, 20, 15, 25, 10])
b = np.array([10, 15, 20, 15, 5])

plt.barh(range(len(a)), a)
plt.barh(range(len(b)), -b)
plt.show()

# %% [markdown]
# ### 多张图

# %%
x = [3,4,5]
y = [3,4,5]
plt.subplot(2,1,1) # 子图， 两行一列中的第一个 
plt.plot(x,y)

x1 = [1,2,3]
y1 = [5,6,7]
plt.subplot(2,1,2)  # 子图， 两行一列中的第二个 

plt.plot(x1,y1)
plt.show()

# %% [markdown]
# ## 正弦函数
# $$ y = \sin(2\pi x ) $$

# %%
x = np.linspace(0,1,100)
y = np.sin(2*np.pi*x)

# plt.figure()
plt.plot(x,y)
plt.title('sin'),plt.xlabel('x'),plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Scipy库
# 读图 ，存图

# %%
from scipy.misc import imread,imsave,imresize 
img = imread('dog.jpg')
print(img.shape)
# img_re = imresize(img,(300,300))
# imsave('dog_re',img_re)
# Out:
# (198, 161, 3)

# %% [markdown]
# ### seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

x = np.random.normal(1, 2, 5000)
y = np.random.normal(-1, 3, 2000)
bins = np.linspace(-10, 10, 30)

plt.hist([x, y], bins, label=['x', 'y'])
plt.legend(loc='upper right')
plt.show()

# %%
a = np.random.rand(200,2)

# %%
plt.scatter(a) #散点图
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0a6126d1398d> in <module>
# ----> 1 plt.scatter(a) #散点图
#       2 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %% [markdown]
# ### pandas 直接plot画图

# %%
iris_data = pd.read_csv('Iris.txt',header = None  ,index_col = None ,encoding = 'utf-8')
iris_data.columns = ['sepal_length','sepal_width','petal_length','petal_width','class']
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data.plot(xticks = np.arange(0,150,10),figsize=(20, 5))  # figsize更改图像长宽
plt.show()

# %%
plt.plot(iris_data['petal_length'])
plt.show()

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'],index=np.arange(10))
df.plot(xticks = np.arange(15),ylim=(0,2),alpha = 0.5 ) #xticks 确定x轴刻度  , ylim确定y轴界限  , alpha设置透明度，0为透明
# kind 确定图像类型，  line折线图， bar柱状图，barh横向柱状图， kde密度图
plt.grid()  # grid添加网格

plt.show()

# %% [markdown]
# ## hist 直接画直方图

# %%
data = pd.Series(np.array([1,3,4,5,4]),index = np.arange(5))
data.hist(alpha= 0.5)  
plt.title('hist')
plt.xlabel('type')
plt.ylabel('number')
plt.legend('person')
plt.show()

# %% [markdown]
# ### 多种legend

# %% [markdown]
# ```python
# Mon.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,legend=True)
# Tue.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,legend =True  )
# Wed.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,legend = True)
# Thu.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,legend = True  )
# Fri.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,legend = True  )
# Sat.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,linestyle = '--',label=True)
# Sun.plot(xticks = np.arange(0,24,2),ylim=(0,70000 ), figsize=(20, 5) , alpha = 0.5,linestyle = '--',label=True)
#
# plt.legend(['Mon', 'Tue' , 'Web' ,'Thu' , 'Fri' , 'Sat' , 'Sun'] )
# plt.title('The number of order in a day in ChongQing')
# ```

# %%
N = 5
men_means = (20, 35, 30, 35, 27)
men_std = (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

women_means = (25, 32, 34, 20, 25)
women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))
